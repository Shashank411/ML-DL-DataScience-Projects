# %%
import pandas as pd
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\user1\\Desktop\\Notebook'

# %%
movies = pd.read_csv("Movie-Ratings.csv")

# %%
movies
# Out:
#                                    Film      Genre  Rotten Tomatoes Ratings %  \
# 0                 (500) Days of Summer      Comedy                         87
# 1                           10,000 B.C.  Adventure                          9
# 2                            12 Rounds      Action                         30
# 3                             127 Hours  Adventure                         93
# 4                             17 Again      Comedy                         55
# 5                                  2012     Action                         39
# 6                            27 Dresses     Comedy                         40
# 7                      30 Days of Night     Horror                         50
# 8                    30 Minutes or Less     Comedy                         43
# 9                                 50/50     Comedy                         93
# 10                           88 Minutes      Drama                          5
# ...

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = [ 'Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
movies.Genre.unique()
# Out:
# array(['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance',
#        'Thriller'], dtype=object)

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film              559 non-null category
# Genre             559 non-null category
# CriticRating      559 non-null int64
# AudienceRating    559 non-null int64
# BudgetMillions    559 non-null int64
# Year              559 non-null category
# dtypes: category(3), int64(3)
# memory usage: 40.3 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
j = sns.jointplot(data= movies , x="CriticRating", y= "AudienceRating" , kind = 'hex' , size = 10)
# Out:
# C:\Users\user1\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
n1 = plt.hist(movies.AudienceRating, bins = 30)

# %%
n1 = plt.hist(movies.CriticRating, bins = 20)

# %% [markdown]
# movies.Genre.cat.categories

# %%
plt.hist(movies[movies.Genre=='Action'].BudgetMillions , bins = 15)
plt.hist(movies[movies.Genre=='Drama'].BudgetMillions , bins = 15)
plt.hist(movies[movies.Genre=='Thriller'].BudgetMillions , bins = 15)
plt.show()

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
list1=[]
mylabels=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre== gen].BudgetMillions)
    mylabels.append(gen)
h = plt.hist(list1 , bins=15 , stacked = True , rwidth = 1 , label= mylabels) 
plt.legend()
plt.show()

# %%
j = sns.jointplot(data= movies , x="CriticRating", y= "AudienceRating" , size = 7)
# Out:
# C:\Users\user1\Anaconda3\lib\site-packages\seaborn\axisgrid.py:2262: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating ,shade= True,shade_lowest= False , cmap='Reds')

# %%
sns.set_style("dark")
f, axes = plt.subplots(1,2, figsize = (12,6) , sharex=True , sharey=True)
a1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating , ax = axes[0])
a2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating , ax = axes[1])
a1.set(xlim= (-20,160))
# Out:
# [(-20, 160)]

# %%
w = sns.boxplot(data= movies[movies.Genre == 'Drama'] , x='Year' , y='CriticRating')

# %%
z = sns.violinplot(data= movies[movies.Genre == 'Drama'] , x='Year' , y='CriticRating')

# %%
g = sns.FacetGrid(movies , row ='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth = 1 , edgecolor = 'black')
g= g.map(plt.scatter , 'CriticRating' , 'AudienceRating' , **kws)

# %%
g = sns.FacetGrid(movies , row ='Genre', col='Year' , hue='Genre')
kws = dict(s=50 , linewidth = 1 , edgecolor = 'black')
g= g.map(plt.scatter , 'CriticRating' , 'AudienceRating' , **kws)
g.set( xlim = (0,100) , ylim = (0,100))
for ax in g.axes.flat :
    ax.plot((0,100) , (0,100) , c='gray' , ls='--')
g.add_legend()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_style("dark")
f, axes = plt.subplots(2,2, figsize = (10,10))
a1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating , shade = True , shade_lowest = True, cmap= 'inferno', ax = axes[0,0])
ab1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating ,cmap = 'cool', ax = axes[0,0])

a2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating , ax = axes[0,1])
z = sns.violinplot(data= movies[movies.Genre == 'Drama'] , x='Year' , y='CriticRating' , ax= axes[1,0])
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating ,shade= True,shade_lowest= False , cmap='Reds', ax = axes[1,1])
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating , cmap='Reds', ax = axes[1,1])
a1.set(xlim= (-20,160))
a2.set(xlim= (-20,160))
plt.show()

# %%
sns.set_style("dark" , {'axes.facecolor' : 'black'})
f, axes = plt.subplots(2,2, figsize = (10,10))
a1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating , shade = True , shade_lowest = True, cmap= 'inferno', ax = axes[0,0])
ab1 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating ,cmap = 'cool', ax = axes[0,0])

a2 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating , ax = axes[0,1])
z = sns.violinplot(data= movies[movies.Genre == 'Drama'] , x='Year' , y='CriticRating' , ax= axes[1,0] , palette = 'YlOrRd')
k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRating ,shade= True,shade_lowest= False , cmap='Blues_r', ax = axes[1,1])
k2 = sns.kdeplot(movies.CriticRating, movies.AudienceRating , cmap='gist_gray_r', ax = axes[1,1])
a1.set(xlim= (-20,160))
a2.set(xlim= (-20,160))
plt.show()

# %%
sns.set_style("whitegrid")
list1=[]
mylabels=[]
for gen in movies.Genre.cat.categories:
    list1.append(movies[movies.Genre== gen].BudgetMillions)
    mylabels.append(gen)
fig , ax =plt.subplots()
fig.set_size_inches(11.7,8.27)
h = plt.hist(list1 , bins=15 , stacked = True , rwidth = 1 , label= mylabels) 
plt.title('Movie Budget Distribution' , fontsize=35,color='DarkBlue',fontname='Console')
plt.ylabel('Number Of Movies',fontsize=25,color='Red')
plt.xlabel('Budget',fontsize=25,color='Green')
plt.yticks(fontsize=20)
plt.xticks(fontsize=20)
plt.legend(prop={'size':20}, frameon=True , fancybox = True,shadow=True , framealpha=1)
plt.show()
